# %% [markdown]
# # Imports

# %%
import polars as pl
import unicodedata
import re

# %% [markdown]
# # Read data

# %%
def read_metro_conexion():

    df = pl.read_csv("/home/onyxia/work/hackathon_mobilites_2025/data/metro_connexion_corresp_idfm_ref.csvin")
    return df

# %%
def normalize_column_name(name: str) -> str:
    # Mettre en minuscules
    name = name.lower()
    # Supprimer les accents
    name = unicodedata.normalize("NFKD", name)
    name = name.encode("ascii", "ignore").decode("utf-8")
    # Remplacer tout caractère non a-z par _
    name = re.sub(r'[^a-z]+', '_', name)
    # Retirer les underscores en trop (début/fin)
    name = name.strip('_')
    return name

# %%
df = read_metro_conexion()
df = df.rename({col: normalize_column_name(col) for col in df.columns})
df.head()
# Out:
# shape: (5, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ href      ┆ provenanc ┆ destinati ┆ station   ┆ … ┆ ligne_de_ ┆ id_zone_a ┆ id_ligne_ ┆ id_ligne │
# │ ---       ┆ e         ┆ on        ┆ ---       ┆   ┆ destinati ┆ rret_icar ┆ de_destin ┆ _de_prov │
# │ str       ┆ ---       ┆ ---       ┆ str       ┆   ┆ on        ┆ ---       ┆ ation     ┆ enance   │
# │           ┆ str       ┆ str       ┆           ┆   ┆ ---       ┆ i64       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆           ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ https://w ┆ Champ de  ┆ Mairie de ┆ Alma -    ┆ … ┆ 9         ┆ 42182     ┆ C01379    ┆ C01727   │
# │ ww.metro- ┆ Mars,     ┆ Montreuil ┆ Marceau   ┆   ┆           ┆           ┆           ┆          │
# │ connexion ┆ Pontoise, ┆           ┆ Pont de   ┆   ┆           ┆           ┆           ┆          │
# │ .or…      ┆ Versa…    ┆           ┆ l'Alma    ┆   ┆           ┆           ┆           ┆          │
# │ https://w ┆ Champ de  ┆ Champ de  ┆ Alma -    ┆ … ┆ C         ┆ 42182     ┆ C01727    ┆ C01727   │
# │ ww.metro- ┆ Mars,     ┆ Mars,     ┆ Marceau   ┆   ┆           ┆           ┆           ┆          │
# │ connexion ┆ Pontoise, ┆ Pontoise, ┆ Pont de   ┆   ┆           ┆           ┆           ┆          │
# │ .or…      ┆ Versa…    ┆ Versa…    ┆ l'Alma    ┆   ┆           ┆           ┆           ┆          │
# │ https://w ┆ Champ de  ┆ Pont de   ┆ Alma -    ┆ … ┆ 9         ┆ 42182     ┆ C01379    ┆ C01727   │
# │ ww.metro- ┆ Mars,     ┆ Sèvres    ┆ Marceau   ┆   ┆           ┆           ┆           ┆          │
# │ connexion ┆ Pontoise, ┆           ┆ Pont de   ┆   ┆           ┆           ┆           ┆          │
# │ .or…      ┆ Versa…    ┆           ┆ l'Alma    ┆   ┆           ┆           ┆           ┆          │
# │ https://w ┆ Choisy-le ┆ Mairie de ┆ Alma -    ┆ … ┆ 9         ┆ 42182     ┆ C01379    ┆ C01727   │
# │ ww.metro- ┆ -Roi, Mas ┆ Montreuil ┆ Marceau   ┆   ┆           ┆           ┆           ┆          │
# │ connexion ┆ sy-Palais ┆           ┆ Pont de   ┆   ┆           ┆           ┆           ┆          │
# │ .or…      ┆ eau…      ┆           ┆ l'Alma    ┆   ┆           ┆           ┆           ┆          │
# │ https://w ┆ Choisy-le ┆ Choisy-le ┆ Alma -    ┆ … ┆ C         ┆ 42182     ┆ C01727    ┆ C01727   │
# │ ww.metro- ┆ -Roi, Mas ┆ -Roi, Mas ┆ Marceau   ┆   ┆           ┆           ┆           ┆          │
# │ connexion ┆ sy-Palais ┆ sy-Palais ┆ Pont de   ┆   ┆           ┆           ┆           ┆          │
# │ .or…      ┆ eau…      ┆ eau…      ┆ l'Alma    ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
#Un exemple : il semblerait que les étapes sont séparées par des retours à la ligne
print(repr(df['description_detaillee'][0]))
print(df['description_detaillee'][0])
# Out:
# "Via la station Alma-Marceau.\r\nLa correspondance du RER C Pont de l'Alma vers le métro Alma-Marceau va se faire par l'extérieur en traversant le pont de l'Alma.\r\n\r\nEn tête, passer les composteurs situés contre le mur.\r\nMonter le double escalier. On arrive à l'extérieur en léger contrebas d'un terre-plein qui se trouve face à nous. Pour monter sur le terre-plein, il y a quatre marches en sortant du RER en provenance de Champ de Mars et une seule marche en sortant du RER en provenance de Bibliothèque François Mitterrand. Ce terre-plein est lui-même légèrement en côte en allant vers la Seine. Il forme une sorte de triangle qui se présente comme suit :Devant, les marches permettant de monter sur le terre-plein, (la base du triangle)De 9 H, à 11 H, un autre terre-plein en terre en contrebas que l'on atteint par un court escalier descendant, (le côté gauche du triangle).\r\nEntre 9 H et 3 H, vers le fond, à une quarantaine de mètres, la SeineA 11 H, le pont de l'alma enjambe la SeineDe 11 H, à 5 H, le quai Branly, (le côté droit du triangle)A 1 H, et à 3 H, à quelques mètres, une guérite de renseignements.\r\nEntre 1 H, et 3 H, un étroit passage qui rejoint l'entrée du RER  en direction de Champ de Mars.Faire 7 mètres en prenant garde à une marche descendante à gauche et à un panneau d'information à hauteur de visage.\r\nMonter quatre marches.\r\nContinuer pendant 10 mètres en longeant au début à droite la guérite d'informations.\r\nObliquer légèrement vers la gauche.\r\nContinuer pendant 14 mètres.\r\nObliquer à gauche.\r\nTraverser le pont pendant une centaine de mètres. On arrive sur la place de l'Alma.\r\nL'Avenue de New York est devant nous, à 7 mètres, avec le passage piéton à 11 H. Il va falloir la traverser en deux fois, car elle est séparée par un terre-plein central en haricot.\r\nObliquer vers 11 H, pendant 7 mètres pour trouver le passage piéton.\r\nTraverser la première partie de l'avenue de New york. On arrive sur un terre-plein avec à gauche un petit embranchement qui relie les deux côtés de l'avenue de New York, le monument à la flamme et le souterrain.\r\nObliquer vers 11 H, pour se diriger vers le second passage piéton.\r\nTraverser le terre-plein pendant 18 mètres.\r\nTraverser la seconde partie de l'avenue de New York. On arrive sur un autre terre-plein avec l'avenue du Président Wilson devant nous et l'entrée du métro Alma-Marceau à 1 H, à quelques mètres.\r\nObliquer vers 1 H, pendant quelques mètres.\r\nDescendre l'escalier. On se trouve à présent dans l'enceinte du métro.\r\nTourner à droite.\r\nDescendre l'escalier.\r\nSuivre le couloir pendant 16 mètres. Celui-ci oblique au début vers la gauche. On arrive dans un carrefour qui se présente comme suit :A 10 H, des portes pour les voyageurs qui sortent du métroA 11 H, des composteurs pour entrer dans le métroA 2 H, un couloir pour les sorties.Passer les composteurs à 11 H. On arrive dans un carrefour en éventail qui se présente comme suit :A 7 H, des portes de sortieA 10 H, un escalier descendant pour la direction de Mairie de MontreuilA 2 H, un escalier descendant pour la direction de Pont de Sèvres.Descendre l'escalier à 10 H.\r\nTourner à droite.\r\nDescendre l'escalier.\r\nOn arrive dans le prolongement du quai en tête."
# Via la station Alma-Marceau.
# La correspondance du RER C Pont de l'Alma vers le métro Alma-Marceau va se faire par l'extérieur en traversant le pont de l'Alma.
#
# En tête, passer les composteurs situés contre le mur.
# Monter le double escalier. On arrive à l'extérieur en léger contrebas d'un terre-plein qui se trouve face à nous. Pour monter sur le terre-plein, il y a quatre marches en sortant du RER en provenance de Champ de Mars et une seule marche en sortant du RER en provenance de Bibliothèque François Mitterrand. Ce terre-plein est lui-même légèrement en côte en allant vers la Seine. Il forme une sorte de triangle qui se présente comme suit :Devant, les marches permettant de monter sur le terre-plein, (la base du triangle)De 9 H, à 11 H, un autre terre-plein en terre en contrebas que l'on atteint par un court escalier descendant, (le côté gauche du triangle).
# Entre 9 H et 3 H, vers le fond, à une quarantaine de mètres, la SeineA 11 H, le pont de l'alma enjambe la SeineDe 11 H, à 5 H, le quai Branly, (le côté droit du triangle)A 1 H, et à 3 H, à quelques mètres, une guérite de renseignements.
# Entre 1 H, et 3 H, un étroit passage qui rejoint l'entrée du RER  en direction de Champ de Mars.Faire 7 mètres en prenant garde à une marche descendante à gauche et à un panneau d'information à hauteur de visage.
# Monter quatre marches.
# Continuer pendant 10 mètres en longeant au début à droite la guérite d'informations.
# Obliquer légèrement vers la gauche.
# Continuer pendant 14 mètres.
# Obliquer à gauche.
# Traverser le pont pendant une centaine de mètres. On arrive sur la place de l'Alma.
# L'Avenue de New York est devant nous, à 7 mètres, avec le passage piéton à 11 H. Il va falloir la traverser en deux fois, car elle est séparée par un terre-plein central en haricot.
# Obliquer vers 11 H, pendant 7 mètres pour trouver le passage piéton.
# Traverser la première partie de l'avenue de New york. On arrive sur un terre-plein avec à gauche un petit embranchement qui relie les deux côtés de l'avenue de New York, le monument à la flamme et le souterrain.
# Obliquer vers 11 H, pour se diriger vers le second passage piéton.
# Traverser le terre-plein pendant 18 mètres.
# Traverser la seconde partie de l'avenue de New York. On arrive sur un autre terre-plein avec l'avenue du Président Wilson devant nous et l'entrée du métro Alma-Marceau à 1 H, à quelques mètres.
# Obliquer vers 1 H, pendant quelques mètres.
# Descendre l'escalier. On se trouve à présent dans l'enceinte du métro.
# Tourner à droite.
# Descendre l'escalier.
# Suivre le couloir pendant 16 mètres. Celui-ci oblique au début vers la gauche. On arrive dans un carrefour qui se présente comme suit :A 10 H, des portes pour les voyageurs qui sortent du métroA 11 H, des composteurs pour entrer dans le métroA 2 H, un couloir pour les sorties.Passer les composteurs à 11 H. On arrive dans un carrefour en éventail qui se présente comme suit :A 7 H, des portes de sortieA 10 H, un escalier descendant pour la direction de Mairie de MontreuilA 2 H, un escalier descendant pour la direction de Pont de Sèvres.Descendre l'escalier à 10 H.
# Tourner à droite.
# Descendre l'escalier.
# On arrive dans le prolongement du quai en tête.

# %% [markdown]
# ### quelques exemples de provenance et destinations; il s'agit uniquement des terminus des différentes lignes

# %%
df.select(["provenance", "ligne_de_provenance"]).unique().sort("ligne_de_provenance")
# Out:
# shape: (56, 2)
# ┌─────────────────────────────────┬─────────────────────┐
# │ provenance                      ┆ ligne_de_provenance │
# │ ---                             ┆ ---                 │
# │ str                             ┆ str                 │
# ╞═════════════════════════════════╪═════════════════════╡
# │ La Défense Grande Arche         ┆ 1                   │
# │ Château de Vincennes            ┆ 1                   │
# │ Boulogne                        ┆ 10                  │
# │ Gare d'Austerlitz               ┆ 10                  │
# │ Chatelet                        ┆ 11                  │
# │ …                               ┆ …                   │
# │ Porte D'Asnières - Marguerite … ┆ T3b                 │
# │ Gare de Noisy-le-Sec            ┆ T4                  │
# │ Bondy                           ┆ T4                  │
# │ Châtillon - Montrouge           ┆ T6                  │
# │ Viroflay Rive droite            ┆ T6                  │
# └─────────────────────────────────┴─────────────────────┘

# %%
df.select(["destination", "ligne_de_destination"]).unique().sort("ligne_de_destination")
# Out:
# shape: (54, 2)
# ┌─────────────────────────────────┬──────────────────────┐
# │ destination                     ┆ ligne_de_destination │
# │ ---                             ┆ ---                  │
# │ str                             ┆ str                  │
# ╞═════════════════════════════════╪══════════════════════╡
# │ Château de Vincennes            ┆ 1                    │
# │ La Défense Grande Arche         ┆ 1                    │
# │ Boulogne                        ┆ 10                   │
# │ Gare d'Austerlitz               ┆ 10                   │
# │ Mairie des Lilas                ┆ 11                   │
# │ …                               ┆ …                    │
# │ Porte de Vincennes              ┆ T3b                  │
# │ Porte D'Asnières - Marguerite … ┆ T3b                  │
# │ Gare de Noisy-le-Sec            ┆ T4                   │
# │ Viroflay Rive droite            ┆ T6                   │
# │ Châtillon - Montrouge           ┆ T6                   │
# └─────────────────────────────────┴──────────────────────┘

# %% [markdown]
# # Create a column with the number of steps in each connecting commute

# %%
df = df.with_columns(
    pl.col("description_detaillee")
      .str.count_matches(r"\r\n")
      .alias("nb_etapes")
)

# %% [markdown]
# # Group by connecting stations

# %%
result = (
    df.group_by("station")
      .agg([
          pl.col("provenance").n_unique().alias("nb_provenance"),
          pl.concat_str(["ligne_de_provenance", "provenance"], separator="-").unique().alias("distinct_provenance"),
          pl.col("destination").n_unique().alias("nb_destination"),
          pl.concat_str(["ligne_de_destination", "destination"], separator="-").unique().alias("distinct_destination"),
          pl.col("nb_etapes").sum().alias("total_nb_etapes")
      ])
)
result.sort('nb_provenance', descending=True)
# Out:
# shape: (127, 6)
# ┌────────────────┬───────────────┬────────────────┬────────────────┬───────────────┬───────────────┐
# │ station        ┆ nb_provenance ┆ distinct_prove ┆ nb_destination ┆ distinct_dest ┆ total_nb_etap │
# │ ---            ┆ ---           ┆ nance          ┆ ---            ┆ ination       ┆ es            │
# │ str            ┆ u32           ┆ ---            ┆ u32            ┆ ---           ┆ ---           │
# │                ┆               ┆ list[str]      ┆                ┆ list[str]     ┆ u32           │
# ╞════════════════╪═══════════════╪════════════════╪════════════════╪═══════════════╪═══════════════╡
# │ Châtelet       ┆ 15            ┆ ["B-Aulnay-sou ┆ 15             ┆ ["4-Porte de  ┆ 9636          │
# │                ┆               ┆ s-Bois,        ┆                ┆ Clignancourt" ┆               │
# │                ┆               ┆ Aéroport…      ┆                ┆ , "1…         ┆               │
# │ Saint-Lazare   ┆ 11            ┆ ["T1-Asnières- ┆ 11             ┆ ["3-Galiéni", ┆ 3990          │
# │                ┆               ┆ Genevilliers - ┆                ┆ "12-Mairie    ┆               │
# │                ┆               ┆ L…             ┆                ┆ d'Aub…        ┆               │
# │ République     ┆ 10            ┆ ["8-Balard",   ┆ 10             ┆ ["3-Galiéni", ┆ 1645          │
# │                ┆               ┆ "5-Bobigny", … ┆                ┆ "5-Bobigny",  ┆               │
# │                ┆               ┆ "9…            ┆                ┆ … "…          ┆               │
# │ Gare de Lyon   ┆ 8             ┆ ["1-Château de ┆ 8              ┆ ["D-Villeneuv ┆ 1364          │
# │                ┆               ┆ Vincennes",    ┆                ┆ e-Saint-Georg ┆               │
# │                ┆               ┆ "1-…           ┆                ┆ es, …         ┆               │
# │ Montparnasse - ┆ 8             ┆ ["T1-Asnières- ┆ 8              ┆ ["4-Porte de  ┆ 1317          │
# │ Bienvenüe      ┆               ┆ Genevilliers - ┆                ┆ Clignancourt" ┆               │
# │                ┆               ┆ L…             ┆                ┆ , "1…         ┆               │
# │ …              ┆ …             ┆ …              ┆ …              ┆ …             ┆ …             │
# │ Haussemann     ┆ 1             ┆ ["E-Chelles,   ┆ 12             ┆ ["T1-Asnières ┆ 2461          │
# │                ┆               ┆ Villiers-sur-M ┆                ┆ -Genevilliers ┆               │
# │                ┆               ┆ arn…           ┆                ┆ - L…          ┆               │
# │ Boulogne -     ┆ 1             ┆ ["10-Boulogne" ┆ 2              ┆ ["T2-Porte de ┆ 59            │
# │ Pont de        ┆               ┆ ]              ┆                ┆ Versailles,   ┆               │
# │ Saint-Cloud    ┆               ┆                ┆                ┆ Parc…         ┆               │
# │ Pré            ┆ 1             ┆ ["7B-Louis     ┆ 3              ┆ ["T3b-Porte   ┆ 110           │
# │ Saint-Gervais  ┆               ┆ Blanc"]        ┆                ┆ de            ┆               │
# │                ┆               ┆                ┆                ┆ Vincennes",   ┆               │
# │                ┆               ┆                ┆                ┆ "T3…          ┆               │
# │ Pont de Sèvres ┆ 1             ┆ ["9-Mairie de  ┆ 3              ┆ ["T2-Porte de ┆ 119           │
# │                ┆               ┆ Montreuil"]    ┆                ┆ Versailles,   ┆               │
# │                ┆               ┆                ┆                ┆ Parc…         ┆               │
# │ Porte Dauphine ┆ 1             ┆ ["2-Nation (2  ┆ 3              ┆ ["C-Choisy-le ┆ 69            │
# │ - Maréchal de  ┆               ┆ par            ┆                ┆ -Roi,         ┆               │
# │ L…             ┆               ┆ Barbès-Roche…  ┆                ┆ Massy-Palai…  ┆               │
# └────────────────┴───────────────┴────────────────┴────────────────┴───────────────┴───────────────┘

# %%
result.write_parquet("/home/onyxia/work/hackathon_mobilites_2025/data/interim/metro_connexion_nombre_etape.parquet")
